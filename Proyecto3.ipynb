# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoAlvarezSar/B2-Analisis-de-Datos-con-Python-2020/blob/master/Proyecto3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Comparación de la fuerza de gravedad

# %%
df = pd.read_csv(

# %%
from scipy import stats
import pandas as pd
df = pd.read_csv('/content/1.csv', index_col=0)
df.head()
df['LogMass'].count()
# Out:
# 66

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(style="whitegrid")
sns.boxplot(x=df['LogMass'])
# Out:
# <Axes: xlabel='LogMass'>

# %%
sns.set(style="whitegrid")
sns.boxplot(x=df['LogMass'])
plt.axvline(df['LogMass'].mean(), c='y')

# %% [markdown]
# Rango Intercuartílico

# %%
iqr = df['LogMass'].quantile(0.75) - df['LogMass'].quantile(0.25)
filtro_inferior = df['LogMass'] > df['LogMass'].quantile(0.25) - (iqr * 1.5)
filtro_superior = df['LogMass'] < df['LogMass'].quantile(0.75) + (iqr * 1.5)

df_filtrado = df[filtro_inferior & filtro_superior]

sns.boxplot(df_filtrado['LogMass'])
# Out:
# <Axes: >
